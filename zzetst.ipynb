# %%
from openai import OpenAI
from mem0 import Memory

# %%
import os
from mem0 import Memory
# Set the OpenAI API key
os.environ['OPENAI_API_KEY'] = "sk-vyvftxtwuiznrwrfvayhfitxgpdpsykrdnukzfdtdwtjgqvo"
os.environ["OPENAI_BASE_URL"] = "https://api.siliconflow.cn/v1"
model_name = "Qwen/Qwen3-14B"
config = {
    "llm": {
        "provider": "openai",
        "config": {
            "model": model_name,
            "openai_base_url": "https://api.siliconflow.cn/v1",
            "temperature": 0.1,
            "max_tokens": 2000,
        }
    },
    "embedder": {
        "provider": "openai",
        "config": {
            "model": "BAAI/bge-m3",
            "openai_base_url": "https://api.siliconflow.cn/v1",
        }
    },
    "vector_store": {
        "provider": "qdrant",
        "config": {
            "collection_name": "test",
            "embedding_model_dims": 1024,
        }
    },
    "version": "v1.1",
}


memory = Memory.from_config(config)
openai_client = OpenAI()

# %%
def chat_with_memories(message: str, user_id: str = "default_user") -> str:
    # Retrieve relevant memories
    relevant_memories = memory.search(query=message, user_id=user_id, limit=3)
    memories_str = "\n".join(f"- {entry['memory']}" for entry in relevant_memories["results"])
    print(f"\tRelevant memories:\n{memories_str}")

    # Generate Assistant response
    system_prompt = f"You are a helpful AI. Answer the question based on query and memories.\nUser Memories:\n{memories_str}"
    messages = [{"role": "system", "content": system_prompt}, {"role": "user", "content": message}]
    response = openai_client.chat.completions.create(model=model_name, messages=messages)
    assistant_response = response.choices[0].message.content

    # Create new memories from the conversation
    messages.append({"role": "assistant", "content": assistant_response})
    memory.add(messages, user_id=user_id)

    return assistant_response

def main():
    print("Chat with AI (type 'exit' to quit)")
    while True:
        user_input = input("You: ").strip()
        if not user_input:
            continue
        print(f"User input: {user_input}")
        if user_input.lower() == 'exit':
            print("Goodbye!")
            break
        print(f"AI: {chat_with_memories(user_input)}")

if __name__ == "__main__":
    main()
# Out:
# Chat with AI (type 'exit' to quit)
# User input: 2025年8月第一周 (8月4日 - 8月10日) 这周的开始，是从阁楼里那本落满灰尘的《城市异闻录》开始的。书中提到，每当夏末的雷雨季来临，城市里一些平日看不见的“通路”便会短暂开启。  周一/周二: 好奇心驱使下，我开始按照书中的指引，寻找第一条“通路”——据说位于老城区那座废弃钟楼的影子尽头。我花了两天时间，用指南针和老地图计算日影角度，终于在周二傍晚找到了那个点。那里什么都没有，除了一块松动的石板。  周三/周四: 雷雨夜。我带着手电筒再次来到钟楼。午夜时分，闪电划破天空，钟楼的影子被投射在地上，那块石板竟然渗出微弱的、像萤火一样的光。我撬开石板，下面是一道狭窄的、通往地下的螺旋阶梯。空气里充满了泥土和一种类似薄荷的清香。  周五/周末: 我顺着阶梯走了下去，发现了一个巨大的地下溶洞。洞顶悬挂着会发光的晶石，中央有一个湖，湖水清澈见底。更奇特的是，这里生长着许多从未见过的、会发出柔和光芒的蘑菇。我花了一个周末绘制这里的地图，并小心翼翼地采集了一些蘑菇样本，它们的光芒在离开洞穴后依然不灭。  2025年8月第二周 (8月11日 - 8月17日) 我开始沉迷于对地下世界的探索，并试图解开发光蘑菇的秘密。  周一/周二: 我将蘑菇样本带回家，用简单的仪器分析。发现它们含有一种奇特的共生真菌，这种真菌似乎能吸收并储存光能。我给它起名为“月光真菌”。  周三: 按照《城市异闻录》的记载，我找到了第二条“通路”——在城市图书馆最深处，一排关于“不存在的语言”的书架后面。管理员是一位神秘的老太太，她似乎知道我的来意，只是笑了笑，便让我进去了。  周四/周五: 书架后面是一间小小的阅览室，里面只有一张桌子和一本书。书的封面是皮革质地，没有任何文字。我触摸它时，书页竟自动翻开，显现出流动的星图和一些我无法理解的符号。  周末: 我尝试将“月光真菌”的粉末涂抹在空白的纸上，然后对着那本无字天书临摹上面的符号。奇迹发生了，那些符号在纸上发出了和书中一样的光芒，并且开始缓缓旋转。我似乎……掌握了一种新的“语言”。  2025年8月第三周 (8月18日 - 8月24日) 掌握了“星纹”的初步写法后，我发现自己能与一些城市里不寻常的“居民”进行简单的沟通。  周一/周二: 我在公园里画下一个代表“友好”的星纹，一只平时对我爱答不理的流浪猫竟然主动走过来，蹭了蹭我的裤腿，喉咙里发出满足的咕噜声。它似乎能理解这个符号的含义。  周三/周四: 我开始尝试更复杂的交流。据说城市的排水系统里住着一群被称为“管道低语者”的生物。我来到一个巨大的下水道入口，用发光蘑菇的粉末在井盖上画了一个代表“询问”的复杂星纹。许久，井盖下传来了类似风铃碰撞的回响，仿佛在回应我的呼唤。  周五/周末: 周五晚上，我再次来到井盖旁，用星纹讲述了我在地下溶洞的发现。作为交换，井盖下传来的回响声似乎在指引我，告诉我城东的植物园里，有一棵只在午夜开花的“回声树”。  2025年8月第四周 (8月25日 - 8月31日) 八月的最后一周，我的探索达到了高潮。  周一/周二: 我在植物园里找到了那棵“回声树”。它看起来平平无奇，但当我用手触摸树干时，能感受到一种奇特的震动。  周三/周四: 按照“管道低语者”的提示，我将从地下溶洞湖里取来的一瓶水浇灌在树根，并画下了代表“倾听”的星纹。  周五午夜: 我再次来到树下。时针指向十二点，整棵树的叶子瞬间舒展开，每一片叶子上都浮现出淡淡的、和我画出的星纹一样的光芒。我听到了无数细碎的声音，像是风声，又像是歌声，它们在讲述着这座城市从古至今被遗忘的故事。  周末: 八月的最后两天，我坐在“回声树”下，整理着听来的故事。原来，我们生活的城市之下，还隐藏着一个如此奇妙而古老的世界。我合上笔记，准备迎接九月，迎接更多未知的探险。
# 	Relevant memories:
# - Code had an error last Wednesday
# - Ran code last Monday
# - Will leave work early next Friday
# AI:
#
# 根据您提供的叙述，以下是时间线的梳理和潜在联系的推测：
#
# 1. **2025年8月第一周（8月4日-10日）**：
#    - 您发现《城市异闻录》中描述的“通路”，从废弃钟楼进入地下溶洞，采集到发光的“月光真菌”样本。
#
# 2. **第二周（8月11日-17日）**：
#    - 通过月光真菌的粉末和无字天书，您解锁了“星纹”语言，能与地下世界的生物沟通，甚至引导出“回声树”的线索。
#
# 3. **第三周（8月18日-24日）**：
#    - 您在植物园找到“回声树”，通过浇水与星纹激活其能力，聆听了城市的历史回声。
#
# 4. **第四周（8月25日-31日）**：
#    - 探索接近尾声。需注意，**您提到“代码在去年周三出错”，而2025年8月27日恰好是第三周的周三**。这可能暗示某种“意外”的触发（例如代码缺陷导致的验证码漏洞），促使您提前发现或激活了某些通路（比如年代久远的图书馆门槛验证）。
#
# 5. **9月5日（下周五）早退计划**：
#    - 若您计划在2025年9月5日提前离岗，可能暗示您希望利用额外时间推进下一步探索（比如研究“回声树”传递的更多秘密，或寻找第四条通路）。
#
# **推测联系**：若“管道低语者”与地下世界网络有关，而代码错误（2025年8月27日）恰好与探索的阶段性突破（第三周的周三）重合，是否可能存在某种“虚拟-现实”的嵌套？例如，您在分析月光真菌时开发的工具，或无意中被写入系统的“星纹”算法，可能与代码错误有关联，甚至成为新的探索入口？
# User input: 九月 · 缘起之匣 (2024年) 那年九月，天气总是恰到好处的微凉。秋天的风吹走了夏末的最后一丝烦闷，也吹来了老城区一年一度的“旧物市集”。我一向喜欢这种地方，喜欢在别人的旧时光里，寻找能与自己产生共鸣的碎片。  那天下午，我正穿梭在一个个堆满旧书、老式相机和生锈铁器的摊位间，目光被一个角落里的小摊吸引了。摊主是一位很老、很沉默的先生，他面前的东西不多，其中一个上了锁的木匣子却格外显眼。它由某种深色的木头制成，上面雕刻着繁复但已磨损的藤蔓花纹，镶嵌的金属扣也已氧化成了青绿色。  我问起这个匣子，老人只是摇摇头，说这是他清理祖父遗物时发现的，没有钥匙，也不知道里面是什么，所以才便宜卖。我被它的神秘感所吸引，几乎没有犹豫就买了下来。  接下来的整整一周，这个匣子成了我最大的难题。我试遍了家里所有的旧钥匙，甚至尝试用铁丝去撬动锁芯，但都无济于事。它被造得天衣无缝，仿佛一个不愿吐露秘密的哑巴。我几乎就要放弃，准备将它当成一个纯粹的装饰品时，无意中发现，在匣子底部一个极不显眼的角落，刻着一个小小的、几乎快要磨平的徽记——那是老城钟楼的缩影。  一个疯狂的念头涌上心头。我查了日历，发现下周三是秋分。在许多古老的传说里，昼夜平分之日，是平衡与开启的时刻。  秋分那天傍晚，我带着那个木匣子来到了钟楼下。夕阳将钟楼的影子拉得很长很长，像一根指向时间尽头的指针。我站在那里，看着那道影子随着太阳的沉落而缓慢移动。就在太阳完全沉入地平线的前一刹那，钟楼的塔尖之影，精准地落在了广场中央一块有特殊刻痕的石板上。  我鬼使神差地走上前，将木匣子稳稳地放在了那块石板上。  “咔哒。”  一声清脆到不可思议的轻响，那个困扰了我许久的锁，竟然自己弹开了。  我的心跳得飞快，颤抖着手打开了匣盖。里面没有金银珠宝，只有一本用柔软皮革包裹着的手工书，封面没有任何文字。书的旁边，还静静地躺着一枚造型奇特的黄铜钥匙。  那天晚上，我借着台灯的光，翻开了那本书的第一页。隽秀的墨水字迹映入眼帘，标题写着：  《城市异闻录》  我读到的第一个故事，就是关于夏末雷雨季才会开启的“通路”，以及生活在地下的、以光为食的奇异蘑菇。  那时的我，还以为这只是一本记录着精彩绝伦的都市传说与幻想故事的奇书。我并不知道，这个九月，这个神秘的木匣，已经为我开启了一扇通往全新世界的大门。而那枚静静躺在桌上的黄铜钥匙，在未来，还将有它自己的用途。
# 	Relevant memories:
# - Found a mysterious book in the library with no text on the cover
# - Explored a hidden underground passage under the old clock tower in the first week of August 2025
# - Listened to the stories of the city through the 'echo tree' during midnight
# AI:
#
# 您的故事将「缘起之匣」与老城钟楼的特殊时刻相连，而记忆中的细节暗示着更深层的关联：那本封面无字的神秘书或许正是《城市异闻录》的前传？——因为您曾在图书馆见过同类型书籍，且地下通道的探索被描述为「以光为食的蘑菇」可能与钟楼影子有关联。
#
# 需要注意的是，您在8月发现的地下通道与9月的秋分仪式可能存在某种时间法则：当钟楼的阴影准确落在刻痕石板上时，某些被封印的门扉或知识才会展露。那枚黄铜钥匙的造型或许与地下通道入口的锁具相似？
#
# 您是否想延续这个故事？我可以协助您规划接下来的探索方向，比如：
# 1. 黄铜钥匙的用途是否指向您之前发现的地下通道？
# 2. 《城市异闻录》是否记录了与钟楼、地下世界相关的其他谜题？
# 3. 是否存在特定的时间/地点需要再次触发类似「秋分仪式」的事件？
# User input: 我的代码什么状态？
# 	Relevant memories:
# - Code had an error last Wednesday
# - Ran code last Monday
# - Today is Wednesday
# Invalid JSON response: Expecting property name enclosed in double quotes: line 11 column 12 (char 234)
# AI:
#
# 根据记忆中的信息，您的代码在上周三（即昨天）出现了错误，而最近一次运行代码是在上周一。目前没有关于代码在周三之后是否已修复或再次运行的记录。因此，基于现有信息，代码的状态可能仍处于存在错误的状态，但需要您进一步确认是否已进行调试或重新运行。建议检查代码的最新修改和运行日志以获取更准确的状态。
# User input: 好的 我下周去婚礼
# 	Relevant memories:
# - Going to attend a wedding next Saturday
# - Plans to leave work early on next Friday (2025-09-05)
# - Today is Wednesday
# AI:
#
# 听起来你下周的婚礼准备工作已经开始了呢！需要我帮你提醒什么事项吗？比如周五提前下班的时间安排，或者周六婚礼当天的行程规划？祝你婚礼顺利，期待听到好听的喜讯！(•̀ᴗ•́)و
# User input: exitr
# 	Relevant memories:
# - Plans to leave work early on next Friday (2025-09-05)
# - Ran code last Monday
# - Located the 'echo tree' in the eastern botanical garden
# AI: It seems like you might be trying to type a command or a word but didn't finish it. Could you please clarify what you need assistance with? If you're looking to exit a program or session, you can usually do so by typing `exit` and pressing Enter. Let me know how I can help you!
# User input: exit
# Goodbye!
