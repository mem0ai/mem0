# %% [markdown]
# ## Cookbook for using Cohere with Embedchain

# %% [markdown]
# ### Step-1: Install embedchain package

# %%
# !pip install embedchain
# Out:
# Requirement already satisfied: embedchain in /usr/local/lib/python3.10/dist-packages (0.0.72)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from embedchain) (4.12.2)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.8 in /usr/local/lib/python3.10/dist-packages (from embedchain) (0.4.14)
# Requirement already satisfied: docx2txt<0.9,>=0.8 in /usr/local/lib/python3.10/dist-packages (from embedchain) (0.8)
# Requirement already satisfied: duckduckgo-search<4.0.0,>=3.8.5 in /usr/local/lib/python3.10/dist-packages (from embedchain) (3.9.3)
# Requirement already satisfied: langchain<0.0.280,>=0.0.279 in /usr/local/lib/python3.10/dist-packages (from embedchain) (0.0.279)
# Requirement already satisfied: openai<0.28.0,>=0.27.5 in /usr/local/lib/python3.10/dist-packages (from embedchain) (0.27.10)
# Requirement already satisfied: pypdf<4.0.0,>=3.11.0 in /usr/local/lib/python3.10/dist-packages (from embedchain) (3.16.4)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from embedchain) (1.0.0)
# Requirement already satisfied: pytube<16.0.0,>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from embedchain) (15.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from embedchain) (2.31.0)
# Requirement already satisfied: tiktoken<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from embedchain) (0.4.0)
# Requirement already satisfied: unstructured[local-inference]<0.11.0,>=0.10.18 in /usr/local/lib/python3.10/dist-packages (from embedchain) (0.10.23)
# Requirement already satisfied: youtube-transcript-api<0.7.0,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from embedchain) (0.6.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain) (2.5)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (1.10.13)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (0.103.2)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (0.23.2)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (3.0.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (4.5.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (3.3.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (1.15.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (0.14.1)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (7.4.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (6.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (1.59.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (4.0.1)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (0.9.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (1.23.5)
# Requirement already satisfied: aiofiles>=23.2.1 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain) (23.2.1)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain) (8.1.7)
# Requirement already satisfied: lxml>=4.9.3 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain) (4.9.3)
# Requirement already satisfied: httpx[brotli,http2,socks]>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain) (0.25.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain) (2.0.21)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain) (3.8.6)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain) (0.5.14)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.21 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain) (0.0.44)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain) (2.8.7)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain) (8.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain) (2023.7.22)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<0.5.0,>=0.4.0->embedchain) (2023.6.3)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (5.2.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.2.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.4.27)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.8.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.9.0)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.8.0)
# Requirement already satisfied: python-iso639 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2023.6.15)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.0.9)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.4.0)
# Requirement already satisfied: backoff in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.2.1)
# Requirement already satisfied: ebooklib in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.18)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.5)
# Requirement already satisfied: python-pptx<=0.6.21 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.6.21)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (20221105)
# Requirement already satisfied: python-docx>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.0.1)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.16.3)
# Requirement already satisfied: msg-parser in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.2.0)
# Requirement already satisfied: unstructured-inference==0.7.5 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.7.5)
# Requirement already satisfied: onnx in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.14.1)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.3.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.1)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.1.2)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.0.1)
# Requirement already satisfied: pypandoc in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.12)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.5.3)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.3.4)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.0.6)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.17.3)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (4.8.0.76)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (4.34.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain) (0.9.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain) (0.27.0)
# Requirement already satisfied: httpcore<0.19.0,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain) (0.18.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain) (1.3.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain) (1.1.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain) (4.1.0)
# Requirement already satisfied: socksio==1.* in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain) (1.0.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain) (23.5.26)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain) (23.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain) (1.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain) (1.6)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain) (2.8.2)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx<=0.6.21->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (9.4.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from python-pptx<=0.6.21->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.1.8)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain<0.0.280,>=0.0.279->embedchain) (3.0.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain) (0.18.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain) (11.0.3)
# Requirement already satisfied: olefile>=0.46 in /usr/local/lib/python3.10/dist-packages (from msg-parser->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.46)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.3.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2023.3.post1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (41.0.4)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain) (1.1.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.16.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain) (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2023.6.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain) (10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.11.3)
# Requirement already satisfied: iopath in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.1.10)
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.10.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.15.2+cu118)
# Requirement already satisfied: effdet in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.4.1)
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.3.10)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.21)
# Requirement already satisfied: timm>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.9.7)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.0.7)
# Requirement already satisfied: omegaconf>=2.0 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (17.0.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.8.2)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (4.21.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (4.9.3)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.1.1)

# %% [markdown]
# ### Step-2: Set Cohere related environment variables and install the dependencies
#
# You can find `OPENAI_API_KEY` on your [OpenAI dashboard](https://platform.openai.com/account/api-keys) and `COHERE_API_KEY` key on your [Cohere dashboard](https://dashboard.cohere.com/api-keys).

# %%
# !pip install embedchain[cohere]
# Out:
# Collecting embedchain[cohere]
#   Downloading embedchain-0.0.72-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 2.1 MB/s eta 0:00:00
# Collecting beautifulsoup4<5.0.0,>=4.12.2 (from embedchain[cohere])
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 6.6 MB/s eta 0:00:00
# Collecting chromadb<0.5.0,>=0.4.8 (from embedchain[cohere])
#   Downloading chromadb-0.4.14-py3-none-any.whl (448 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.1/448.1 kB 8.7 MB/s eta 0:00:00
# Collecting docx2txt<0.9,>=0.8 (from embedchain[cohere])
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting duckduckgo-search<4.0.0,>=3.8.5 (from embedchain[cohere])
#   Downloading duckduckgo_search-3.9.3-py3-none-any.whl (25 kB)
# Collecting langchain<0.0.280,>=0.0.279 (from embedchain[cohere])
#   Downloading langchain-0.0.279-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.1 MB/s eta 0:00:00
# Collecting openai<0.28.0,>=0.27.5 (from embedchain[cohere])
#   Downloading openai-0.27.10-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 7.5 MB/s eta 0:00:00
# Collecting pypdf<4.0.0,>=3.11.0 (from embedchain[cohere])
#   Downloading pypdf-3.16.4-py3-none-any.whl (276 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.6/276.6 kB 11.3 MB/s eta 0:00:00
# Collecting python-dotenv<2.0.0,>=1.0.0 (from embedchain[cohere])
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting pytube<16.0.0,>=15.0.0 (from embedchain[cohere])
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from embedchain[cohere]) (2.31.0)
# Collecting tiktoken<0.5.0,>=0.4.0 (from embedchain[cohere])
#   Downloading tiktoken-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 35.0 MB/s eta 0:00:00
# Collecting unstructured[local-inference]<0.11.0,>=0.10.18 (from embedchain[cohere])
#   Downloading unstructured-0.10.23-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 35.1 MB/s eta 0:00:00
# Collecting youtube-transcript-api<0.7.0,>=0.6.1 (from embedchain[cohere])
#   Downloading youtube_transcript_api-0.6.1-py3-none-any.whl (24 kB)
# Collecting cohere<5.0,>=4.27 (from embedchain[cohere])
#   Downloading cohere-4.27-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain[cohere]) (2.5)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (1.10.13)
# Collecting chroma-hnswlib==0.7.3 (from chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 51.6 MB/s eta 0:00:00
# Collecting fastapi>=0.95.2 (from chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading fastapi-0.103.2-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 8.0 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 6.7 MB/s eta 0:00:00
# Collecting posthog>=2.4.0 (from chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (4.5.0)
# Collecting pulsar-client>=3.1.0 (from chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading pulsar_client-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 71.0 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1 (from chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading onnxruntime-1.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 89.5 MB/s eta 0:00:00
# Collecting tokenizers>=0.13.2 (from chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 98.4 MB/s eta 0:00:00
# Collecting pypika>=0.48.9 (from chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 7.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (4.66.1)
# Collecting overrides>=7.3.1 (from chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (6.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (1.59.0)
# Collecting bcrypt>=4.0.1 (from chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 37.5 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (0.9.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (1.23.5)
# Requirement already satisfied: aiohttp<4.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from cohere<5.0,>=4.27->embedchain[cohere]) (3.8.6)
# Collecting backoff<3.0,>=2.0 (from cohere<5.0,>=4.27->embedchain[cohere])
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting fastavro==1.8.2 (from cohere<5.0,>=4.27->embedchain[cohere])
#   Downloading fastavro-1.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 28.5 MB/s eta 0:00:00
# Requirement already satisfied: importlib_metadata<7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from cohere<5.0,>=4.27->embedchain[cohere]) (6.8.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from cohere<5.0,>=4.27->embedchain[cohere]) (2.0.6)
# Collecting aiofiles>=23.2.1 (from duckduckgo-search<4.0.0,>=3.8.5->embedchain[cohere])
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain[cohere]) (8.1.7)
# Requirement already satisfied: lxml>=4.9.3 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain[cohere]) (4.9.3)
# Collecting httpx[brotli,http2,socks]>=0.25.0 (from duckduckgo-search<4.0.0,>=3.8.5->embedchain[cohere])
#   Downloading httpx-0.25.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[cohere]) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[cohere]) (2.0.21)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[cohere]) (4.0.3)
# Collecting dataclasses-json<0.6.0,>=0.5.7 (from langchain<0.0.280,>=0.0.279->embedchain[cohere])
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Collecting langsmith<0.1.0,>=0.0.21 (from langchain<0.0.280,>=0.0.279->embedchain[cohere])
#   Downloading langsmith-0.0.44-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[cohere]) (2.8.7)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[cohere]) (8.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain[cohere]) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain[cohere]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain[cohere]) (2023.7.22)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<0.5.0,>=0.4.0->embedchain[cohere]) (2023.6.3)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (5.2.0)
# Collecting filetype (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting python-magic (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (3.8.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (0.9.0)
# Collecting emoji (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 35.5 MB/s eta 0:00:00
# Collecting python-iso639 (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading python_iso639-2023.6.15-py3-none-any.whl (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.1/275.1 kB 29.5 MB/s eta 0:00:00
# Collecting langdetect (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 71.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rapidfuzz (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading rapidfuzz-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 68.3 MB/s eta 0:00:00
# Collecting ebooklib (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading EbookLib-0.18.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.5/115.5 kB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (3.5)
# Collecting python-pptx<=0.6.21 (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading python-pptx-0.6.21.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 99.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pdfminer.six (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 100.9 MB/s eta 0:00:00
# Collecting python-docx>=1.0.1 (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading python_docx-1.0.1-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.4/237.4 kB 25.7 MB/s eta 0:00:00
# Collecting pdf2image (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading pdf2image-1.16.3-py3-none-any.whl (11 kB)
# Collecting msg-parser (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading msg_parser-1.2.0-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 11.9 MB/s eta 0:00:00
# Collecting unstructured-inference==0.7.5 (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading unstructured_inference-0.7.5-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 7.3 MB/s eta 0:00:00
# Collecting onnx (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading onnx-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 38.9 MB/s eta 0:00:00
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading unstructured.pytesseract-0.3.12-py3-none-any.whl (14 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (3.1)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (3.1.2)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (2.0.1)
# Collecting pypandoc (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading pypandoc-1.12-py3-none-any.whl (20 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (1.5.3)
# Collecting layoutparser[layoutmodels,tesseract] (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading layoutparser-0.3.4-py3-none-any.whl (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 41.6 MB/s eta 0:00:00
# Collecting python-multipart (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.2 MB/s eta 0:00:00
# Collecting huggingface-hub (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 31.5 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (4.8.0.76)
# Collecting onnxruntime>=1.14.1 (from chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 103.5 MB/s eta 0:00:00
# Collecting transformers>=4.25.1 (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 100.0 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere<5.0,>=4.27->embedchain[cohere]) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere<5.0,>=4.27->embedchain[cohere]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere<5.0,>=4.27->embedchain[cohere]) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere<5.0,>=4.27->embedchain[cohere]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere<5.0,>=4.27->embedchain[cohere]) (1.3.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain[cohere])
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.5 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain[cohere])
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.2 MB/s eta 0:00:00
# Collecting httpcore<0.19.0,>=0.18.0 (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[cohere])
#   Downloading httpcore-0.18.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[cohere]) (1.3.0)
# Collecting brotli (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[cohere])
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 74.9 MB/s eta 0:00:00
# Collecting h2<5,>=3 (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[cohere])
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.9 MB/s eta 0:00:00
# Collecting socksio==1.* (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[cohere])
#   Downloading socksio-1.0.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib_metadata<7.0,>=6.0->cohere<5.0,>=4.27->embedchain[cohere]) (3.17.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (23.5.26)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (23.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (1.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (1.16.0)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (2.8.2)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx<=0.6.21->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (9.4.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<=0.6.21->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading XlsxWriter-3.1.8-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain<0.0.280,>=0.0.279->embedchain[cohere]) (3.0.0)
# Collecting huggingface-hub (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 27.1 MB/s eta 0:00:00
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.4 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 30.4 MB/s eta 0:00:00
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading uvloop-0.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 70.9 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.1 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 13.4 MB/s eta 0:00:00
# Collecting olefile>=0.46 (from msg-parser->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading olefile-0.46.zip (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 12.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (1.3.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (2023.3.post1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (41.0.4)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (1.1.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (1.16.0)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[cohere])
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[cohere])
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (2023.6.0)
# Collecting safetensors>=0.3.1 (from transformers>=4.25.1->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.6 MB/s eta 0:00:00
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain[cohere])
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[cohere])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (1.11.3)
# Collecting iopath (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pdfplumber (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading pdfplumber-0.10.2-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 kB 5.5 MB/s eta 0:00:00
# Collecting pytesseract (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (0.15.2+cu118)
# Collecting effdet (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[cohere]) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (2.21)
# Collecting timm>=0.9.2 (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading timm-0.9.7-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 92.4 MB/s eta 0:00:00
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (2.0.7)
# Collecting omegaconf>=2.0 (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (17.0.2)
# Collecting portalocker (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading pypdfium2-4.21.0-py3-none-manylinux_2_17_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 96.3 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (3.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[cohere]) (3.1.1)
# Building wheels for collected packages: docx2txt, pypika, python-pptx, ebooklib, langdetect, olefile, iopath, antlr4-python3-runtime
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3959 sha256=5619ec4c4048f8b42e058a41c9d264508ae8b32837b27febee08369551b78f1d
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=718cae0ba4171d8f60f2f1bab4c3e0f6d8f3d452dfe5fae15f26326bd92cee7e
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
#   Building wheel for python-pptx (setup.py) ... done
#   Created wheel for python-pptx: filename=python_pptx-0.6.21-py3-none-any.whl size=470932 sha256=8c57c8a579107d74b41b4e022f5b291ccc554e796310acc440871515c9fe0156
#   Stored in directory: /root/.cache/pip/wheels/ea/dd/74/01b3ec7256a0800b99384e9a0f7620e358afc3a51a59bf9b49
#   Building wheel for ebooklib (setup.py) ... done
#   Created wheel for ebooklib: filename=EbookLib-0.18-py3-none-any.whl size=38778 sha256=d390e311cae10168910a20d30db6da45c73538ef1377b685f6ed5e90e772a911
#   Stored in directory: /root/.cache/pip/wheels/0f/38/cc/a3728bb72a315d9d8766fb71d362136372066fc25ad838f8fa
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=81b46b0c0c675e7fa58facd2465cb446d6f416ea9bedd6b382f86184a01a3cff
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for olefile (setup.py) ... done
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35417 sha256=8971944a5bd09f6add597e4861fa3f26c63043ddfbcb9e83795fcb4b775552b0
#   Stored in directory: /root/.cache/pip/wheels/02/39/c0/9eb1f7a42b4b38f6f333b6314d4ed11c46f12a0f7b78194f0d
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31530 sha256=eaad260b4425939849da9ce3b9fb31a52b66c6a09631e07fa20263b399ccf8b7
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=db6a963a2e1308a7b1d4750d75fa89e0c8ee81d6e0138b274b3aa6c94386fbfe
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built docx2txt pypika python-pptx ebooklib langdetect olefile iopath antlr4-python3-runtime
# Installing collected packages: pypika, monotonic, filetype, docx2txt, brotli, antlr4-python3-runtime, XlsxWriter, websockets, uvloop, unstructured.pytesseract, socksio, safetensors, rapidfuzz, pytube, python-multipart, python-magic, python-iso639, python-dotenv, python-docx, pytesseract, pypdfium2, pypdf, pypandoc, pulsar-client, portalocker, pdf2image, overrides, onnx, omegaconf, olefile, mypy-extensions, marshmallow, langdetect, hyperframe, humanfriendly, httptools, hpack, h11, fastavro, emoji, ebooklib, chroma-hnswlib, beautifulsoup4, bcrypt, backoff, aiofiles, youtube-transcript-api, watchfiles, uvicorn, typing-inspect, tiktoken, starlette, python-pptx, posthog, msg-parser, langsmith, iopath, huggingface-hub, httpcore, h2, coloredlogs, tokenizers, pdfminer.six, openai, onnxruntime, httpx, fastapi, dataclasses-json, cohere, unstructured, transformers, pdfplumber, langchain, chromadb, layoutparser, duckduckgo-search, timm, effdet, unstructured-inference, embedchain
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.2
#     Uninstalling beautifulsoup4-4.11.2:
#       Successfully uninstalled beautifulsoup4-4.11.2
# Successfully installed XlsxWriter-3.1.8 aiofiles-23.2.1 antlr4-python3-runtime-4.9.3 backoff-2.2.1 bcrypt-4.0.1 beautifulsoup4-4.12.2 brotli-1.1.0 chroma-hnswlib-0.7.3 chromadb-0.4.14 cohere-4.27 coloredlogs-15.0.1 dataclasses-json-0.5.14 docx2txt-0.8 duckduckgo-search-3.9.3 ebooklib-0.18 effdet-0.4.1 embedchain-0.0.72 emoji-2.8.0 fastapi-0.103.2 fastavro-1.8.2 filetype-1.2.0 h11-0.14.0 h2-4.1.0 hpack-4.0.0 httpcore-0.18.0 httptools-0.6.1 httpx-0.25.0 huggingface-hub-0.17.3 humanfriendly-10.0 hyperframe-6.0.1 iopath-0.1.10 langchain-0.0.279 langdetect-1.0.9 langsmith-0.0.44 layoutparser-0.3.4 marshmallow-3.20.1 monotonic-1.6 msg-parser-1.2.0 mypy-extensions-1.0.0 olefile-0.46 omegaconf-2.3.0 onnx-1.14.1 onnxruntime-1.15.1 openai-0.27.10 overrides-7.4.0 pdf2image-1.16.3 pdfminer.six-20221105 pdfplumber-0.10.2 portalocker-2.8.2 posthog-3.0.2 pulsar-client-3.3.0 pypandoc-1.12 pypdf-3.16.4 pypdfium2-4.21.0 pypika-0.48.9 pytesseract-0.3.10 python-docx-1.0.1 python-dotenv-1.0.0 python-iso639-2023.6.15 python-magic-0.4.27 python-multipart-0.0.6 python-pptx-0.6.21 pytube-15.0.0 rapidfuzz-3.4.0 safetensors-0.4.0 socksio-1.0.0 starlette-0.27.0 tiktoken-0.4.0 timm-0.9.7 tokenizers-0.14.1 transformers-4.34.0 typing-inspect-0.9.0 unstructured-0.10.23 unstructured-inference-0.7.5 unstructured.pytesseract-0.3.12 uvicorn-0.23.2 uvloop-0.18.0 watchfiles-0.21.0 websockets-11.0.3 youtube-transcript-api-0.6.1

# %%
import os
from embedchain import App

os.environ["OPENAI_API_KEY"] = "sk-xxx"
os.environ["COHERE_API_KEY"] = "xxx"

# %% [markdown]
# ### Step-3: Define your llm and embedding model config

# %%
config = """
llm:
  provider: cohere
  config:
    model: gptd-instruct-tft
    temperature: 0.5
    max_tokens: 1000
    top_p: 1
    stream: false
"""

# Write the multi-line string to a YAML file
with open('cohere.yaml', 'w') as file:
    file.write(config)

# %% [markdown]
# ### Step-4 Create embedchain app based on the config

# %%
app = App.from_config(yaml_path="cohere.yaml")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-17c554869cc4> in <cell line: 1>()
# ----> 1 app = App.from_config(yaml_path="cohere.yaml")
#
# /usr/local/lib/python3.10/dist-packages/embedchain/apps/app.py in from_config(cls, yaml_path)
#     142
#     143         embedder_provider = embedder_config_data.get("provider", "openai")
# --> 144         embedder = EmbedderFactory.create(embedder_provider, embedder_config_data.get("config", {}))
#     145         return cls(config=app_config, llm=llm, db=db, embedder=embedder)
#
# /usr/local/lib/python3.10/dist-packages/embedchain/factory.py in create(cls, provider_name, config_data)
#      62             embedder_class = load_class(class_type)
#      63             embedder_config_class = load_class(config_class_type)
# ---> 64             return embedder_class(config=embedder_config_class(**config_data))
#      65         else:
#      66             raise ValueError(f"Unsupported Embedder provider: {provider_name}")
#
# /usr/local/lib/python3.10/dist-packages/embedchain/embedder/openai.py in __init__(self, config)
#      28         else:
#      29             if os.getenv("OPENAI_API_KEY") is None and os.getenv("OPENAI_ORGANIZATION") is None:
# ---> 30                 raise ValueError(
#      31                     "OPENAI_API_KEY or OPENAI_ORGANIZATION environment variables not provided"
#      32                 )  # noqa:E501
#
# ValueError: OPENAI_API_KEY or OPENAI_ORGANIZATION environment variables not provided

# %% [markdown]
# ### Step-5: Add data sources to your app

# %%
app.add("https://www.forbes.com/profile/elon-musk")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bf8621710fb1> in <cell line: 1>()
# ----> 1 app.add("https://www.forbes.com/profile/elon-musk")
#
# NameError: name 'app' is not defined

# %% [markdown]
# ### Step-6: All set. Now start asking questions related to your data

# %%
while(True):
    question = input("Enter question: ")
    if question in ['q', 'exit', 'quit']:
        break
    answer = app.query(question)
    print(answer)
# Out:
# Enter question: who is elon musk?
#  Elon Musk is a entrepreneur who is known for co-founding multiple successful companies, including Tesla, SpaceX, and Twitter.  He is also one of the richest people in the world, and uses his wealth for philanthropic purposes.
# Enter question: q
