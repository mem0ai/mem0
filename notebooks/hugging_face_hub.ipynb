# %% [markdown]
# ## Cookbook for using Hugging Face Hub with Embedchain

# %% [markdown]
# ### Step-1: Install embedchain package

# %%
# !pip install embedchain
# Out:
# Collecting embedchain
#   Downloading embedchain-0.0.72-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 2.0 MB/s eta 0:00:00
# Collecting beautifulsoup4<5.0.0,>=4.12.2 (from embedchain)
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 8.9 MB/s eta 0:00:00
# Collecting chromadb<0.5.0,>=0.4.8 (from embedchain)
#   Downloading chromadb-0.4.14-py3-none-any.whl (448 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.1/448.1 kB 21.9 MB/s eta 0:00:00
# Collecting docx2txt<0.9,>=0.8 (from embedchain)
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting duckduckgo-search<4.0.0,>=3.8.5 (from embedchain)
#   Downloading duckduckgo_search-3.9.3-py3-none-any.whl (25 kB)
# Collecting langchain<0.0.280,>=0.0.279 (from embedchain)
#   Downloading langchain-0.0.279-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 44.8 MB/s eta 0:00:00
# Collecting openai<0.28.0,>=0.27.5 (from embedchain)
#   Downloading openai-0.27.10-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 8.5 MB/s eta 0:00:00
# Collecting pypdf<4.0.0,>=3.11.0 (from embedchain)
#   Downloading pypdf-3.16.4-py3-none-any.whl (276 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.6/276.6 kB 27.5 MB/s eta 0:00:00
# Collecting python-dotenv<2.0.0,>=1.0.0 (from embedchain)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting pytube<16.0.0,>=15.0.0 (from embedchain)
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from embedchain) (2.31.0)
# Collecting tiktoken<0.5.0,>=0.4.0 (from embedchain)
#   Downloading tiktoken-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 69.6 MB/s eta 0:00:00
# Collecting unstructured[local-inference]<0.11.0,>=0.10.18 (from embedchain)
#   Downloading unstructured-0.10.23-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 77.7 MB/s eta 0:00:00
# Collecting youtube-transcript-api<0.7.0,>=0.6.1 (from embedchain)
#   Downloading youtube_transcript_api-0.6.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain) (2.5)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (1.10.13)
# Collecting chroma-hnswlib==0.7.3 (from chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 79.5 MB/s eta 0:00:00
# Collecting fastapi>=0.95.2 (from chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading fastapi-0.103.2-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 6.7 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 6.6 MB/s eta 0:00:00
# Collecting posthog>=2.4.0 (from chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (4.5.0)
# Collecting pulsar-client>=3.1.0 (from chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading pulsar_client-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 66.6 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1 (from chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading onnxruntime-1.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 73.5 MB/s eta 0:00:00
# Collecting tokenizers>=0.13.2 (from chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 38.7 MB/s eta 0:00:00
# Collecting pypika>=0.48.9 (from chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 6.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (4.66.1)
# Collecting overrides>=7.3.1 (from chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (6.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (1.59.0)
# Collecting bcrypt>=4.0.1 (from chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 39.2 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (0.9.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain) (1.23.5)
# Collecting aiofiles>=23.2.1 (from duckduckgo-search<4.0.0,>=3.8.5->embedchain)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain) (8.1.7)
# Requirement already satisfied: lxml>=4.9.3 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain) (4.9.3)
# Collecting httpx[brotli,http2,socks]>=0.25.0 (from duckduckgo-search<4.0.0,>=3.8.5->embedchain)
#   Downloading httpx-0.25.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain) (2.0.21)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain) (3.8.6)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain) (4.0.3)
# Collecting dataclasses-json<0.6.0,>=0.5.7 (from langchain<0.0.280,>=0.0.279->embedchain)
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Collecting langsmith<0.1.0,>=0.0.21 (from langchain<0.0.280,>=0.0.279->embedchain)
#   Downloading langsmith-0.0.44-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain) (2.8.7)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain) (8.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain) (2023.7.22)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<0.5.0,>=0.4.0->embedchain) (2023.6.3)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (5.2.0)
# Collecting filetype (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting python-magic (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.8.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.9.0)
# Collecting emoji (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 30.1 MB/s eta 0:00:00
# Collecting python-iso639 (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading python_iso639-2023.6.15-py3-none-any.whl (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.1/275.1 kB 26.1 MB/s eta 0:00:00
# Collecting langdetect (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 57.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rapidfuzz (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading rapidfuzz-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 23.1 MB/s eta 0:00:00
# Collecting backoff (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting ebooklib (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading EbookLib-0.18.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.5/115.5 kB 13.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.5)
# Collecting python-pptx<=0.6.21 (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading python-pptx-0.6.21.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 98.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pdfminer.six (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 105.9 MB/s eta 0:00:00
# Collecting python-docx>=1.0.1 (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading python_docx-1.0.1-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.4/237.4 kB 27.2 MB/s eta 0:00:00
# Collecting pdf2image (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading pdf2image-1.16.3-py3-none-any.whl (11 kB)
# Collecting msg-parser (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading msg_parser-1.2.0-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 10.6 MB/s eta 0:00:00
# Collecting unstructured-inference==0.7.5 (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading unstructured_inference-0.7.5-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 7.4 MB/s eta 0:00:00
# Collecting onnx (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading onnx-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 81.6 MB/s eta 0:00:00
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading unstructured.pytesseract-0.3.12-py3-none-any.whl (14 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.1)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.1.2)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.0.1)
# Collecting pypandoc (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading pypandoc-1.12-py3-none-any.whl (20 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.5.3)
# Collecting layoutparser[layoutmodels,tesseract] (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading layoutparser-0.3.4-py3-none-any.whl (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 73.9 MB/s eta 0:00:00
# Collecting python-multipart (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.0 MB/s eta 0:00:00
# Collecting huggingface-hub (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 32.4 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (4.8.0.76)
# Collecting onnxruntime>=1.14.1 (from chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 101.3 MB/s eta 0:00:00
# Collecting transformers>=4.25.1 (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 29.6 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain) (1.3.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.0 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.0 MB/s eta 0:00:00
# Collecting httpcore<0.19.0,>=0.18.0 (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain)
#   Downloading httpcore-0.18.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain) (1.3.0)
# Collecting h2<5,>=3 (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.4 MB/s eta 0:00:00
# Collecting brotli (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain)
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 95.6 MB/s eta 0:00:00
# Collecting socksio==1.* (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain)
#   Downloading socksio-1.0.0-py3-none-any.whl (12 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain) (23.5.26)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain) (23.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain) (1.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain) (1.16.0)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain) (2.8.2)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx<=0.6.21->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (9.4.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<=0.6.21->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading XlsxWriter-3.1.8-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 16.5 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain<0.0.280,>=0.0.279->embedchain) (3.0.0)
# Collecting huggingface-hub (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 31.6 MB/s eta 0:00:00
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.0 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 32.7 MB/s eta 0:00:00
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading uvloop-0.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 79.0 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.8 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 13.7 MB/s eta 0:00:00
# Collecting olefile>=0.46 (from msg-parser->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading olefile-0.46.zip (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.3.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2023.3.post1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (41.0.4)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain) (1.1.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.16.0)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2023.6.0)
# Collecting safetensors>=0.3.1 (from transformers>=4.25.1->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.3 MB/s eta 0:00:00
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.11.3)
# Collecting iopath (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pdfplumber (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading pdfplumber-0.10.2-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.15.2+cu118)
# Collecting effdet (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 14.3 MB/s eta 0:00:00
# Collecting pytesseract (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.21)
# Collecting timm>=0.9.2 (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading timm-0.9.7-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 82.4 MB/s eta 0:00:00
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.0.7)
# Collecting omegaconf>=2.0 (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (17.0.2)
# Collecting portalocker (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading pypdfium2-4.21.0-py3-none-manylinux_2_17_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 93.5 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain) (3.1.1)
# Building wheels for collected packages: docx2txt, pypika, python-pptx, ebooklib, langdetect, olefile, iopath, antlr4-python3-runtime
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3959 sha256=b5bdb9ae7b4a39b88320b31575057c85af4c77f7bc49adf2ae9fa9c2d54fea63
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=dd2d6e28ef5fd531fc3c94a3097ce32815e87e00106c4118ce4f0ff4d747f72e
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
#   Building wheel for python-pptx (setup.py) ... done
#   Created wheel for python-pptx: filename=python_pptx-0.6.21-py3-none-any.whl size=470932 sha256=da8754116079e95e77da571910c4a0ac26afa11fce3af1f436a98c88db223712
#   Stored in directory: /root/.cache/pip/wheels/ea/dd/74/01b3ec7256a0800b99384e9a0f7620e358afc3a51a59bf9b49
#   Building wheel for ebooklib (setup.py) ... done
#   Created wheel for ebooklib: filename=EbookLib-0.18-py3-none-any.whl size=38778 sha256=12ca2a131d613f13374ba07b0b7ae17f6ade5586f94c4184503af98963b0da2f
#   Stored in directory: /root/.cache/pip/wheels/0f/38/cc/a3728bb72a315d9d8766fb71d362136372066fc25ad838f8fa
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=2659830a699ded8b0ce08548f73517e9ffa90de2ba4742f82af3606b6c78ca22
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for olefile (setup.py) ... done
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35417 sha256=ecedf96b0655792996df4db6260a563ebcc53f207f4c03f1370ca289e59c0938
#   Stored in directory: /root/.cache/pip/wheels/02/39/c0/9eb1f7a42b4b38f6f333b6314d4ed11c46f12a0f7b78194f0d
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31530 sha256=b868bcae0e6f38a728590374ea536cc21a223438eaaa009b0a096f19c98a7529
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=6ad60f4888273dee2053ce6a47f6c7f63675d21238559c634d8b0e7799fa2912
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built docx2txt pypika python-pptx ebooklib langdetect olefile iopath antlr4-python3-runtime
# Installing collected packages: pypika, monotonic, filetype, docx2txt, brotli, antlr4-python3-runtime, XlsxWriter, websockets, uvloop, unstructured.pytesseract, socksio, safetensors, rapidfuzz, pytube, python-multipart, python-magic, python-iso639, python-dotenv, python-docx, pytesseract, pypdfium2, pypdf, pypandoc, pulsar-client, portalocker, pdf2image, overrides, onnx, omegaconf, olefile, mypy-extensions, marshmallow, langdetect, hyperframe, humanfriendly, httptools, hpack, h11, emoji, ebooklib, chroma-hnswlib, beautifulsoup4, bcrypt, backoff, aiofiles, youtube-transcript-api, watchfiles, uvicorn, typing-inspect, tiktoken, starlette, python-pptx, posthog, msg-parser, langsmith, iopath, huggingface-hub, httpcore, h2, coloredlogs, tokenizers, pdfminer.six, openai, onnxruntime, httpx, fastapi, dataclasses-json, unstructured, transformers, pdfplumber, langchain, chromadb, layoutparser, duckduckgo-search, timm, effdet, unstructured-inference, embedchain
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.2
#     Uninstalling beautifulsoup4-4.11.2:
#       Successfully uninstalled beautifulsoup4-4.11.2
# Successfully installed XlsxWriter-3.1.8 aiofiles-23.2.1 antlr4-python3-runtime-4.9.3 backoff-2.2.1 bcrypt-4.0.1 beautifulsoup4-4.12.2 brotli-1.1.0 chroma-hnswlib-0.7.3 chromadb-0.4.14 coloredlogs-15.0.1 dataclasses-json-0.5.14 docx2txt-0.8 duckduckgo-search-3.9.3 ebooklib-0.18 effdet-0.4.1 embedchain-0.0.72 emoji-2.8.0 fastapi-0.103.2 filetype-1.2.0 h11-0.14.0 h2-4.1.0 hpack-4.0.0 httpcore-0.18.0 httptools-0.6.1 httpx-0.25.0 huggingface-hub-0.17.3 humanfriendly-10.0 hyperframe-6.0.1 iopath-0.1.10 langchain-0.0.279 langdetect-1.0.9 langsmith-0.0.44 layoutparser-0.3.4 marshmallow-3.20.1 monotonic-1.6 msg-parser-1.2.0 mypy-extensions-1.0.0 olefile-0.46 omegaconf-2.3.0 onnx-1.14.1 onnxruntime-1.15.1 openai-0.27.10 overrides-7.4.0 pdf2image-1.16.3 pdfminer.six-20221105 pdfplumber-0.10.2 portalocker-2.8.2 posthog-3.0.2 pulsar-client-3.3.0 pypandoc-1.12 pypdf-3.16.4 pypdfium2-4.21.0 pypika-0.48.9 pytesseract-0.3.10 python-docx-1.0.1 python-dotenv-1.0.0 python-iso639-2023.6.15 python-magic-0.4.27 python-multipart-0.0.6 python-pptx-0.6.21 pytube-15.0.0 rapidfuzz-3.4.0 safetensors-0.4.0 socksio-1.0.0 starlette-0.27.0 tiktoken-0.4.0 timm-0.9.7 tokenizers-0.14.1 transformers-4.34.0 typing-inspect-0.9.0 unstructured-0.10.23 unstructured-inference-0.7.5 unstructured.pytesseract-0.3.12 uvicorn-0.23.2 uvloop-0.18.0 watchfiles-0.21.0 websockets-11.0.3 youtube-transcript-api-0.6.1

# %% [markdown]
# ### Step-2: Set Hugging Face Hub related environment variables and install dependencies
#
# You can find your `HUGGINGFACE_ACCESS_TOKEN` key on your [Hugging Face Hub dashboard](https://huggingface.co/settings/tokens) and install the dependencies

# %%
# !pip install embedchain[huggingface-hub]
# Out:
# Requirement already satisfied: embedchain[huggingface-hub] in /usr/local/lib/python3.10/dist-packages (0.0.72)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from embedchain[huggingface-hub]) (4.12.2)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.8 in /usr/local/lib/python3.10/dist-packages (from embedchain[huggingface-hub]) (0.4.14)
# Requirement already satisfied: docx2txt<0.9,>=0.8 in /usr/local/lib/python3.10/dist-packages (from embedchain[huggingface-hub]) (0.8)
# Requirement already satisfied: duckduckgo-search<4.0.0,>=3.8.5 in /usr/local/lib/python3.10/dist-packages (from embedchain[huggingface-hub]) (3.9.3)
# Requirement already satisfied: langchain<0.0.280,>=0.0.279 in /usr/local/lib/python3.10/dist-packages (from embedchain[huggingface-hub]) (0.0.279)
# Requirement already satisfied: openai<0.28.0,>=0.27.5 in /usr/local/lib/python3.10/dist-packages (from embedchain[huggingface-hub]) (0.27.10)
# Requirement already satisfied: pypdf<4.0.0,>=3.11.0 in /usr/local/lib/python3.10/dist-packages (from embedchain[huggingface-hub]) (3.16.4)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from embedchain[huggingface-hub]) (1.0.0)
# Requirement already satisfied: pytube<16.0.0,>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from embedchain[huggingface-hub]) (15.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from embedchain[huggingface-hub]) (2.31.0)
# Requirement already satisfied: tiktoken<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from embedchain[huggingface-hub]) (0.4.0)
# Requirement already satisfied: unstructured[local-inference]<0.11.0,>=0.10.18 in /usr/local/lib/python3.10/dist-packages (from embedchain[huggingface-hub]) (0.10.23)
# Requirement already satisfied: youtube-transcript-api<0.7.0,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from embedchain[huggingface-hub]) (0.6.1)
# Requirement already satisfied: huggingface_hub<0.18.0,>=0.17.3 in /usr/local/lib/python3.10/dist-packages (from embedchain[huggingface-hub]) (0.17.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain[huggingface-hub]) (2.5)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (1.10.13)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (0.103.2)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (0.23.2)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (3.0.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (4.5.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (3.3.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (1.15.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (0.14.1)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (7.4.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (6.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (1.59.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (4.0.1)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (0.9.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (1.23.5)
# Requirement already satisfied: aiofiles>=23.2.1 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain[huggingface-hub]) (23.2.1)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain[huggingface-hub]) (8.1.7)
# Requirement already satisfied: lxml>=4.9.3 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain[huggingface-hub]) (4.9.3)
# Requirement already satisfied: httpx[brotli,http2,socks]>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain[huggingface-hub]) (0.25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<0.18.0,>=0.17.3->embedchain[huggingface-hub]) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<0.18.0,>=0.17.3->embedchain[huggingface-hub]) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<0.18.0,>=0.17.3->embedchain[huggingface-hub]) (6.0.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<0.18.0,>=0.17.3->embedchain[huggingface-hub]) (23.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (2.0.21)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (3.8.6)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (0.5.14)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.21 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (0.0.44)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (2.8.7)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (8.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain[huggingface-hub]) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain[huggingface-hub]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain[huggingface-hub]) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain[huggingface-hub]) (2023.7.22)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<0.5.0,>=0.4.0->embedchain[huggingface-hub]) (2023.6.3)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (5.2.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (1.2.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.4.27)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (3.8.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.9.0)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (2.8.0)
# Requirement already satisfied: python-iso639 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (2023.6.15)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (1.0.9)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (3.4.0)
# Requirement already satisfied: backoff in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (2.2.1)
# Requirement already satisfied: ebooklib in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.18)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (3.5)
# Requirement already satisfied: python-pptx<=0.6.21 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.6.21)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (20221105)
# Requirement already satisfied: python-docx>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (1.0.1)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (1.16.3)
# Requirement already satisfied: msg-parser in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (1.2.0)
# Requirement already satisfied: unstructured-inference==0.7.5 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.7.5)
# Requirement already satisfied: onnx in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (1.14.1)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.3.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (3.1)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (3.1.2)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (2.0.1)
# Requirement already satisfied: pypandoc in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (1.12)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (1.5.3)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.3.4)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.0.6)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (4.8.0.76)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (4.34.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (0.9.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (0.27.0)
# Requirement already satisfied: httpcore<0.19.0,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[huggingface-hub]) (0.18.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[huggingface-hub]) (1.3.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[huggingface-hub]) (1.1.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[huggingface-hub]) (4.1.0)
# Requirement already satisfied: socksio==1.* in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[huggingface-hub]) (1.0.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (23.5.26)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (1.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (1.6)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (2.8.2)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx<=0.6.21->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (9.4.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from python-pptx<=0.6.21->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (3.1.8)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (3.0.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (0.18.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (11.0.3)
# Requirement already satisfied: olefile>=0.46 in /usr/local/lib/python3.10/dist-packages (from msg-parser->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.46)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (1.3.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (2023.3.post1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (41.0.4)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (1.1.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (1.16.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[huggingface-hub]) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[huggingface-hub]) (4.0.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain[huggingface-hub]) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (1.11.3)
# Requirement already satisfied: iopath in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.1.10)
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.10.2)
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.3.10)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (2.0.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.15.1)
# Requirement already satisfied: effdet in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.4.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[huggingface-hub]) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (2.21)
# Requirement already satisfied: timm>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.9.7)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (2.0.7)
# Requirement already satisfied: omegaconf>=2.0 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (2.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.41.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (17.0.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (2.8.2)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (4.21.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (4.9.3)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (3.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[huggingface-hub]) (3.1.1)

# %%
# !pip install embedchain[opensource]
# Out:
# Requirement already satisfied: embedchain[opensource] in /usr/local/lib/python3.10/dist-packages (0.0.72)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (4.12.2)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.8 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (0.4.14)
# Requirement already satisfied: docx2txt<0.9,>=0.8 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (0.8)
# Requirement already satisfied: duckduckgo-search<4.0.0,>=3.8.5 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (3.9.3)
# Requirement already satisfied: langchain<0.0.280,>=0.0.279 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (0.0.279)
# Requirement already satisfied: openai<0.28.0,>=0.27.5 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (0.27.10)
# Requirement already satisfied: pypdf<4.0.0,>=3.11.0 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (3.16.4)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (1.0.0)
# Requirement already satisfied: pytube<16.0.0,>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (15.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (2.31.0)
# Requirement already satisfied: tiktoken<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (0.4.0)
# Requirement already satisfied: unstructured[local-inference]<0.11.0,>=0.10.18 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (0.10.23)
# Requirement already satisfied: youtube-transcript-api<0.7.0,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (0.6.1)
# Requirement already satisfied: gpt4all==1.0.8 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (1.0.8)
# Requirement already satisfied: sentence-transformers<3.0.0,>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (2.2.2)
# Requirement already satisfied: torch==2.0.0 in /usr/local/lib/python3.10/dist-packages (from embedchain[opensource]) (2.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gpt4all==1.0.8->embedchain[opensource]) (4.66.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->embedchain[opensource]) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.0->embedchain[opensource]) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.0->embedchain[opensource]) (0.41.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0->embedchain[opensource]) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0->embedchain[opensource]) (17.0.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain[opensource]) (2.5)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (1.10.13)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (0.103.2)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (0.23.2)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (3.0.2)
# Requirement already satisfied: pulsar-client>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (3.3.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (1.15.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (0.14.1)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (7.4.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (6.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (1.59.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (4.0.1)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (0.9.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (1.23.5)
# Requirement already satisfied: aiofiles>=23.2.1 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain[opensource]) (23.2.1)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain[opensource]) (8.1.7)
# Requirement already satisfied: lxml>=4.9.3 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain[opensource]) (4.9.3)
# Requirement already satisfied: httpx[brotli,http2,socks]>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from duckduckgo-search<4.0.0,>=3.8.5->embedchain[opensource]) (0.25.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[opensource]) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[opensource]) (2.0.21)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[opensource]) (3.8.6)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[opensource]) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[opensource]) (0.5.14)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.21 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[opensource]) (0.0.44)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[opensource]) (2.8.7)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.0.280,>=0.0.279->embedchain[opensource]) (8.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain[opensource]) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain[opensource]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain[opensource]) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->embedchain[opensource]) (2023.7.22)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->embedchain[opensource]) (4.34.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->embedchain[opensource]) (0.15.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->embedchain[opensource]) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->embedchain[opensource]) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->embedchain[opensource]) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->embedchain[opensource]) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->embedchain[opensource]) (0.17.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<0.5.0,>=0.4.0->embedchain[opensource]) (2023.6.3)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (5.2.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (1.2.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.4.27)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.9.0)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (2.8.0)
# Requirement already satisfied: python-iso639 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (2023.6.15)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (1.0.9)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (3.4.0)
# Requirement already satisfied: backoff in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (2.2.1)
# Requirement already satisfied: ebooklib in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.18)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (3.5)
# Requirement already satisfied: python-pptx<=0.6.21 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.6.21)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (20221105)
# Requirement already satisfied: python-docx>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (1.0.1)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (1.16.3)
# Requirement already satisfied: msg-parser in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (1.2.0)
# Requirement already satisfied: unstructured-inference==0.7.5 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.7.5)
# Requirement already satisfied: onnx in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (1.14.1)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.3.12)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (3.1.2)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (2.0.1)
# Requirement already satisfied: pypandoc in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (1.12)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (1.5.3)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.3.4)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.0.6)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (4.8.0.76)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain[opensource]) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain[opensource]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain[opensource]) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain[opensource]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.0.280,>=0.0.279->embedchain[opensource]) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain[opensource]) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain[opensource]) (0.9.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (0.27.0)
# Requirement already satisfied: httpcore<0.19.0,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[opensource]) (0.18.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[opensource]) (1.3.0)
# Requirement already satisfied: socksio==1.* in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[opensource]) (1.0.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[opensource]) (1.1.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.10/dist-packages (from httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[opensource]) (4.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers<3.0.0,>=2.2.2->embedchain[opensource]) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers<3.0.0,>=2.2.2->embedchain[opensource]) (23.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (23.5.26)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (3.20.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (1.6)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (2.8.2)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx<=0.6.21->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (9.4.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from python-pptx<=0.6.21->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (3.1.8)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain<0.0.280,>=0.0.279->embedchain[opensource]) (3.0.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers<3.0.0,>=2.2.2->embedchain[opensource]) (0.4.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (0.18.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (11.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.0->embedchain[opensource]) (2.1.3)
# Requirement already satisfied: olefile>=0.46 in /usr/local/lib/python3.10/dist-packages (from msg-parser->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.46)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers<3.0.0,>=2.2.2->embedchain[opensource]) (1.3.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (2023.3.post1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (41.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers<3.0.0,>=2.2.2->embedchain[opensource]) (3.2.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.0->embedchain[opensource]) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (1.1.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (1.16.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[opensource]) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.25.0->duckduckgo-search<4.0.0,>=3.8.5->embedchain[opensource]) (4.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain<0.0.280,>=0.0.279->embedchain[opensource]) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.8->embedchain[opensource]) (10.0)
# Requirement already satisfied: iopath in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.1.10)
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.10.2)
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.3.10)
# Requirement already satisfied: effdet in /usr/local/lib/python3.10/dist-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (2.21)
# Requirement already satisfied: timm>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.9.7)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (2.0.7)
# Requirement already satisfied: omegaconf>=2.0 in /usr/local/lib/python3.10/dist-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (2.3.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (2.8.2)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (4.21.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (4.9.3)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.5->unstructured[local-inference]<0.11.0,>=0.10.18->embedchain[opensource]) (3.1.1)

# %%
import os
from embedchain import App

os.environ["HUGGINGFACE_ACCESS_TOKEN"] = "hf_xxx"

# %% [markdown]
# ### Step-3: Define your llm and embedding model config

# %%
config = """
llm:
  provider: huggingface
  config:
    model: 'google/flan-t5-xxl'
    temperature: 0.5
    max_tokens: 1000
    top_p: 0.8
    stream: false

embedder:
  provider: huggingface
  config:
    model: 'sentence-transformers/all-mpnet-base-v2'
"""

# Write the multi-line string to a YAML file
with open('huggingface.yaml', 'w') as file:
    file.write(config)

# %% [markdown]
# ### Step-4 Create embedchain app based on the config

# %%
app = App.from_config(yaml_path="huggingface.yaml")

# %% [markdown]
# ### Step-5: Add data sources to your app

# %%
app.add("https://www.forbes.com/profile/elon-musk")
# Out:
# Doc content has changed. Recomputing chunks and embeddings intelligently.
# Successfully saved https://www.forbes.com/profile/elon-musk (DataType.WEB_PAGE). New chunks count: 13
# '8cf46026cabf9b05394a2658bd1fe890'

# %% [markdown]
# ### Step-6: All set. Now start asking questions related to your data

# %%
while(True):
    question = input("Enter question: ")
    if question in ['q', 'exit', 'quit']:
        break
    answer = app.query(question)
    print(answer)
# Out:
# Enter question: who is elon musk?
# a tech entrepreneur
# Enter question: what is elon
# CEO
# Enter question: q
